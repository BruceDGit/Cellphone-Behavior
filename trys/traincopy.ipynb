# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import pandas as pd
import os
from sklearn.model_selection import StratifiedKFold
import gc

kfcv_seed = 1998
kfold_func = StratifiedKFold
data_enhance_method = []
k = 5

data_path = ''

def set_data_enhance(val):
    if not isinstance(val, list):
        val = [val]
    global data_enhance_method
    data_enhance_method = val

mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
    4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
    8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
    12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
    16: 'C_2', 17: 'C_5', 18: 'C_6'}

reversed_mapping = {value: key for key, value in mapping.items()}

def decode_label(label_code):
    str = mapping[label_code]
    scene_code = ord(str.split('_')[0]) - ord('A')
    action_code = ord(str.split('_')[1]) - ord('0')
    return scene_code, action_code

def kfcv_evaluate(model_name, x, y):
    kfold = kfold_func(n_splits=k, shuffle=True, random_state=kfcv_seed)
    evals = {'loss':0.0, 'accuracy':0.0}
    index = 0

    for train, val in kfold.split(x, np.argmax(y, axis=-1)):
        print('Processing fold: %d (%d, %d)' % (index, len(train), len(val)))
        
        model = keras.models.load_model(data_path + '/models/%s/part_%d.h5' % (model_name, index))

        loss, acc = model.evaluate(x=x[val], y=y[val])
        evals['loss'] += loss / k
        evals['accuracy'] += acc / k
        index += 1
    return evals

def kfcv_predict(model_name, inputs):
    path = data_path + '/models/' + model_name + '/'
    models = []
    for i in range(k):
        models.append(keras.models.load_model(path + 'part_%d.h5' % i))

    print('%s loaded.' % model_name)
    result = []
    for j in range(k):
        result.append(models[j].predict(inputs))

    print('result got')
    result = sum(result) / k
    return result

def kfcv_fit(builder, x, y, epochs, checkpoint_path, verbose=2, batch_size=64):
  kfold = kfold_func(n_splits=k, shuffle=True, random_state=kfcv_seed)
  histories = []
  evals = []

  if checkpoint_path[len(checkpoint_path) - 1] != '/':
      checkpoint_path += '/'

  for i in range(k):
    if os.path.exists(checkpoint_path + 'part_%d.h5' % i):
        os.remove(checkpoint_path + 'part_%d.h5' % i)

  for index, (train, val) in enumerate(kfold.split(x, np.argmax(y, axis=-1))):
      print('Processing fold: %d (%d, %d)' % (index, len(train), len(val)))
      model = builder()

      x_train = x[train]
      y_train = y[train]

      if len(data_enhance_method) > 0:
          x_train_copy = np.copy(x_train)
          y_train_copy = np.copy(y_train)
          for method in data_enhance_method:
              x_, y_ = data_enhance(method, x_train_copy, y_train_copy)
              x_train = np.r_[x_train, x_]
              y_train = np.r_[y_train, y_]
          x_train, y_train = shuffle(x_train, y_train)
          print('Data enhanced (%s) => %d' % (' '.join(data_enhance_method), len(x_train)))

      checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path + 'part_%d.h5' % index,
                                monitor='val_accuracy',
                                verbose=0,
                                mode='max',
                                save_best_only=True)

      class_weights = np.array([0.0357285 , 0.08708201, 0.05632962, 0.03861465, 0.07593551,
       0.04339172, 0.09335191, 0.02657245, 0.04090366, 0.0294586 ,
       0.02935908, 0.0678742 , 0.12012341, 0.03324045, 0.01582404,
       0.06458997, 0.06220143, 0.02866242, 0.05075637])
      h = model.fit(x=x_train, y=y_train,
              epochs=epochs,
              verbose=verbose,
              validation_data=(x[val], y[val]),
              callbacks=[checkpoint],
              batch_size=batch_size,
              class_weight=dict(enumerate((1-class_weights)**2)),
              shuffle=True
              )
      evals.append(model.evaluate(x=x[val], y=y[val]))
      histories.append(h)
      del model
      gc.collect()
  return histories, evals

def data_enhance(method, train_data, train_labels):
    if method == 'noise':
        # # noise = train_data
        noise = train_data + np.random.normal(0, 0.1, size=train_data.shape)
        # noise2 = train_data + np.random.uniform(-0.3, 0.3, train_data.shape)
        # noise = np.r_[noise1, noise2]
        # train_labels = np.r_[train_labels1, train_labels1]
        return noise, train_labels
    
    elif method == 'mixup':
        index = [i for i in range(len(train_labels))]
        np.random.shuffle(index)

        x_mixup = np.zeros(train_data.shape)
        y_mixup = np.zeros(train_labels.shape)

        for i in range(len(train_labels)):
            x1 = train_data[i]
            x2 = train_data[index[i]]
            y1 = train_labels[i]
            y2 = train_labels[index[i]]

            factor = np.random.beta(0.2, 0.2)

            x_mixup[i] = x1 * factor + x2 * (1 - factor)
            y_mixup[i] = y1 * factor + y2 * (1 - factor)

        return x_mixup, y_mixup

def save_results(path, output):
    print('saving...')

    df_r = pd.DataFrame(columns=['fragment_id', 'behavior_id'])
    for i in range(len(output)):
        behavior_id = output[i]
        df_r = df_r.append(
            {'fragment_id': i, 'behavior_id': behavior_id}, ignore_index=True)
    df_r.to_csv(path, index=False)

def infer(model_name, inputs, csv_output):
    proba_t = kfcv_predict(model_name, inputs)
    output = np.argmax(proba_t, axis=-1)
    save_results(csv_output, output)
    print('- END -')
    print('Your file locates at %s' % csv_output)
    pd.DataFrame(proba_t, columns = ['pred_{}'.format(i) for i in range(19)]).to_csv(data_path + '/dataset/proba_open777.csv', index= False)

def shuffle(data, labels, seed=None):
    index = [i for i in range(len(labels))]
    if seed != None:
        np.random.seed(seed)
    np.random.shuffle(index)
    return data[index], labels[index]



import tensorflow as tf
import numpy as np
from tensorflow import keras

def BLOCK(seq, filters, kernal_size):
    cnn = keras.layers.Conv1D(filters, 1, padding='SAME', activation='relu')(seq)
    cnn = keras.layers.LayerNormalization()(cnn)

    cnn = keras.layers.Conv1D(filters, kernal_size, padding='SAME', activation='relu')(cnn)
    cnn = keras.layers.LayerNormalization()(cnn)

    cnn = keras.layers.Conv1D(filters, 1, padding='SAME', activation='relu')(cnn)
    cnn = keras.layers.LayerNormalization()(cnn)

    seq = keras.layers.Conv1D(filters, 1)(seq)
    seq = keras.layers.Add()([seq, cnn])
    return seq

def BLOCK2(seq, filters=128, kernal_size=5):
    seq = BLOCK(seq, filters, kernal_size)
    seq = keras.layers.MaxPooling1D(2)(seq)
    seq = keras.layers.SpatialDropout1D(0.3)(seq)
    seq = BLOCK(seq, filters//2, kernal_size)
    seq = keras.layers.GlobalAveragePooling1D()(seq)
    return seq

def ComplexConv1D(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape[1:])
    seq_3 = BLOCK2(inputs, kernal_size=3)
    seq_5 = BLOCK2(inputs, kernal_size=5)
    seq_7 = BLOCK2(inputs, kernal_size=7)
    seq = keras.layers.concatenate([seq_3, seq_5, seq_7])
    seq = keras.layers.Dense(512, activation='relu')(seq)
    seq = keras.layers.Dropout(0.3)(seq)
    seq = keras.layers.Dense(128, activation='relu')(seq)
    seq = keras.layers.Dropout(0.3)(seq)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(seq)

    model = keras.models.Model(inputs=[inputs], outputs=[outputs])

    model.compile(optimizer=tf.optimizers.Adam(1e-3),
            loss=tf.losses.CategoricalCrossentropy(label_smoothing=0.1),           
            metrics=['accuracy'])

    return model



import pandas as pd
import numpy as np
import random
import pickle
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# 特征列名称
src_names = ['acc_x', 'acc_y', 'acc_z', 'acc_xg', 'acc_yg', 'acc_zg', 'acc', 'acc_g']

def handle_features(data):
    data.drop(columns=['time_point'], inplace=True)

    data['acc'] = (data.acc_x ** 2 + data.acc_y ** 2 + data.acc_z ** 2) ** 0.5
    data['acc_g'] = (data.acc_xg ** 2 + data.acc_yg ** 2 + data.acc_zg ** 2) ** 0.5
    # data['acc_g_sub'] = ((data.acc_xg - data.acc_x) ** 2 + (data.acc_yg - data.acc_y) ** 2 + (data.acc_zg - data.acc_z) ** 2) ** 0.5

    return data

# 构造numpy特征矩阵
def handle_mats(grouped_data):
    mats = [i.values for i in grouped_data]
    # padding
    for i in range(len(mats)):
        padding_times = 61 - mats[i].shape[0]
        for j in range(padding_times):
            mats[i] = np.append(mats[i], [[0 for _ in range(mats[i].shape[1])]], axis=0)

    mats_padded = np.zeros([len(mats), 61, mats[0].shape[1]])
    for i in range(len(mats)):
        mats_padded[i] = mats[i]

    return mats_padded

def get_test_data(use_scaler=True):
    FILE_NAME = data_path + "dataset/sensor_test.csv"
    data = handle_features(pd.read_csv(FILE_NAME))
    if use_scaler:
        with open('scaler.pkl', 'rb') as f:
            scaler = pickle.load(f)
        data[src_names] = scaler.transform(data[src_names].values)

    grouped_data = [i.drop(columns='fragment_id') for _, i in data.groupby('fragment_id')]
    return handle_mats(grouped_data)

def get_train_data(use_scaler=True, shuffle=True, pseudo_labels_file=None):
    df = pd.read_csv(data_path + "/dataset/sensor_train.csv")

    # 简单拼接伪标签
    if pseudo_labels_file != None:
        df = df.append(pd.read_csv(pseudo_labels_file))
    data = handle_features(df)

    # 标准化，并将统计值保存
    if use_scaler:
        scaler = StandardScaler()
        scaler.fit(data[src_names].values)  
        with open('scaler.pkl', 'wb') as f:
            pickle.dump(scaler, f)
        data[src_names] = scaler.transform(data[src_names].values)

    grouped_data = [i.drop(columns='fragment_id') for _, i in data.groupby('fragment_id')]
    train_labels = np.array([int(i.iloc[0]['behavior_id']) for i in grouped_data])
    for i in range(len(grouped_data)):
        grouped_data[i].drop(columns='behavior_id', inplace=True)
    train_data = handle_mats(grouped_data)
    
    if shuffle:
        index = [i for i in range(len(train_labels))]
        np.random.seed(2020)
        np.random.shuffle(index)

        train_data = train_data[index]
        train_labels = train_labels[index]

    return train_data, train_labels

def get_train_test_data(use_scaler=True, shuffle=True, pseudo_labels_file=None):
    train_data, train_lables = get_train_data(use_scaler, shuffle, pseudo_labels_file=pseudo_labels_file)
    test_data = get_test_data(use_scaler)
    return train_data, train_lables, test_data

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
# from utils import *
# from models import *
# from preprocess import *

# 导入精心挑选的pseudo labels
train_data, train_labels, test_data = get_train_test_data(pseudo_labels_file=data_path + '/dataset/pick.csv')
# 设置数据增强方式 (noise, mixup or both)
set_data_enhance(['noise'])

# %%
# 转换成float32节省显存，以及one_hot编码
num_classes = 19
train_data = tf.cast(train_data, tf.float32).numpy()
train_labels = tf.one_hot(train_labels, num_classes).numpy()

# %%
# 训练
histories, evals = kfcv_fit(builder=lambda : ComplexConv1D(train_data.shape, 19),
                                x=train_data, y=train_labels,
                                epochs=40,
                                checkpoint_path = data_path + '/models/conv1d/',
                                batch_size=64
                                )
# Out:
# Processing fold: 0 (8038, 2010)
# Data enhanced (noise) => 24114
# Epoch 1/40
# 377/377 - 8s - loss: 1.6767 - accuracy: 0.4905 - val_loss: 1.4900 - val_accuracy: 0.6159
# Epoch 2/40
# 377/377 - 6s - loss: 1.3681 - accuracy: 0.6210 - val_loss: 1.3842 - val_accuracy: 0.6731
# Epoch 3/40
# 377/377 - 6s - loss: 1.2479 - accuracy: 0.6788 - val_loss: 1.2893 - val_accuracy: 0.7174
# Epoch 4/40
# 377/377 - 6s - loss: 1.1693 - accuracy: 0.7200 - val_loss: 1.1875 - val_accuracy: 0.7751
# Epoch 5/40
# 377/377 - 6s - loss: 1.1089 - accuracy: 0.7502 - val_loss: 1.1543 - val_accuracy: 0.7791
# Epoch 6/40
# 377/377 - 6s - loss: 1.0629 - accuracy: 0.7725 - val_loss: 1.1274 - val_accuracy: 0.7841
# Epoch 7/40
# 377/377 - 6s - loss: 1.0268 - accuracy: 0.7878 - val_loss: 1.0986 - val_accuracy: 0.8090
# Epoch 8/40
# 377/377 - 6s - loss: 0.9922 - accuracy: 0.8046 - val_loss: 1.1085 - val_accuracy: 0.8000
# Epoch 9/40
# 377/377 - 7s - loss: 0.9618 - accuracy: 0.8196 - val_loss: 1.0502 - val_accuracy: 0.8338
# Epoch 10/40
# 377/377 - 6s - loss: 0.9389 - accuracy: 0.8311 - val_loss: 1.0418 - val_accuracy: 0.8269
# Epoch 11/40
# 377/377 - 6s - loss: 0.9096 - accuracy: 0.8437 - val_loss: 1.0392 - val_accuracy: 0.8249
# Epoch 12/40
# 377/377 - 6s - loss: 0.8868 - accuracy: 0.8541 - val_loss: 1.0018 - val_accuracy: 0.8398
# Epoch 13/40
# 377/377 - 6s - loss: 0.8676 - accuracy: 0.8653 - val_loss: 1.0185 - val_accuracy: 0.8383
# Epoch 14/40
# 377/377 - 7s - loss: 0.8491 - accuracy: 0.8741 - val_loss: 1.0039 - val_accuracy: 0.8423
# Epoch 15/40
# 377/377 - 6s - loss: 0.8267 - accuracy: 0.8872 - val_loss: 0.9781 - val_accuracy: 0.8532
# Epoch 16/40
# 377/377 - 6s - loss: 0.8124 - accuracy: 0.8923 - val_loss: 0.9891 - val_accuracy: 0.8498
# Epoch 17/40
# 377/377 - 6s - loss: 0.7961 - accuracy: 0.8992 - val_loss: 0.9830 - val_accuracy: 0.8453
# Epoch 18/40
# 377/377 - 6s - loss: 0.7880 - accuracy: 0.9036 - val_loss: 1.0166 - val_accuracy: 0.8398
# Epoch 19/40
# 377/377 - 6s - loss: 0.7768 - accuracy: 0.9092 - val_loss: 0.9773 - val_accuracy: 0.8537
# Epoch 20/40
# 377/377 - 6s - loss: 0.7608 - accuracy: 0.9172 - val_loss: 0.9535 - val_accuracy: 0.8697
# Epoch 21/40
# 377/377 - 6s - loss: 0.7522 - accuracy: 0.9214 - val_loss: 0.9463 - val_accuracy: 0.8637
# Epoch 22/40
# 377/377 - 6s - loss: 0.7377 - accuracy: 0.9258 - val_loss: 0.9851 - val_accuracy: 0.8602
# Epoch 23/40
# 377/377 - 6s - loss: 0.7313 - accuracy: 0.9307 - val_loss: 0.9555 - val_accuracy: 0.8672
# Epoch 24/40
# 377/377 - 6s - loss: 0.7171 - accuracy: 0.9392 - val_loss: 0.9868 - val_accuracy: 0.8547
# Epoch 25/40
# 377/377 - 6s - loss: 0.7099 - accuracy: 0.9404 - val_loss: 0.9638 - val_accuracy: 0.8652
# Epoch 26/40
# 377/377 - 6s - loss: 0.7092 - accuracy: 0.9406 - val_loss: 0.9566 - val_accuracy: 0.8667
# Epoch 27/40
# 377/377 - 6s - loss: 0.6933 - accuracy: 0.9487 - val_loss: 0.9802 - val_accuracy: 0.8562
# Epoch 28/40
# 377/377 - 6s - loss: 0.6908 - accuracy: 0.9487 - val_loss: 0.9728 - val_accuracy: 0.8627
# Epoch 29/40
# 377/377 - 6s - loss: 0.6818 - accuracy: 0.9515 - val_loss: 0.9488 - val_accuracy: 0.8687
# Epoch 30/40
# 377/377 - 6s - loss: 0.6760 - accuracy: 0.9545 - val_loss: 0.9613 - val_accuracy: 0.8587
# Epoch 31/40
# 377/377 - 7s - loss: 0.6686 - accuracy: 0.9590 - val_loss: 0.9559 - val_accuracy: 0.8716
# Epoch 32/40
# 377/377 - 6s - loss: 0.6659 - accuracy: 0.9579 - val_loss: 0.9681 - val_accuracy: 0.8652
# Epoch 33/40
# 377/377 - 6s - loss: 0.6588 - accuracy: 0.9607 - val_loss: 0.9770 - val_accuracy: 0.8617
# Epoch 34/40
# 377/377 - 6s - loss: 0.6550 - accuracy: 0.9619 - val_loss: 0.9937 - val_accuracy: 0.8627
# Epoch 35/40
# 377/377 - 6s - loss: 0.6455 - accuracy: 0.9688 - val_loss: 0.9679 - val_accuracy: 0.8642
# Epoch 36/40
# 377/377 - 6s - loss: 0.6433 - accuracy: 0.9683 - val_loss: 0.9498 - val_accuracy: 0.8746
# Epoch 37/40
# 377/377 - 6s - loss: 0.6441 - accuracy: 0.9679 - val_loss: 0.9620 - val_accuracy: 0.8667
# Epoch 38/40
# 377/377 - 6s - loss: 0.6392 - accuracy: 0.9686 - val_loss: 0.9585 - val_accuracy: 0.8697
# Epoch 39/40
# 377/377 - 6s - loss: 0.6323 - accuracy: 0.9713 - val_loss: 0.9880 - val_accuracy: 0.8632
# Epoch 40/40
# 377/377 - 6s - loss: 0.6320 - accuracy: 0.9725 - val_loss: 0.9612 - val_accuracy: 0.8667
# 63/63 [==============================] - 0s 6ms/step - loss: 0.9612 - accuracy: 0.8667
# Processing fold: 1 (8038, 2010)
# Data enhanced (noise) => 24114
# Epoch 1/40
# 377/377 - 7s - loss: 1.6838 - accuracy: 0.4849 - val_loss: 1.5213 - val_accuracy: 0.6259
# Epoch 2/40
# 377/377 - 6s - loss: 1.3849 - accuracy: 0.6140 - val_loss: 1.3458 - val_accuracy: 0.7015
# Epoch 3/40
# 377/377 - 6s - loss: 1.2608 - accuracy: 0.6716 - val_loss: 1.2611 - val_accuracy: 0.7463
# Epoch 4/40
# 377/377 - 6s - loss: 1.1825 - accuracy: 0.7157 - val_loss: 1.1933 - val_accuracy: 0.7682
# Epoch 5/40
# 377/377 - 7s - loss: 1.1133 - accuracy: 0.7433 - val_loss: 1.1429 - val_accuracy: 0.7721
# Epoch 6/40
# 377/377 - 6s - loss: 1.0720 - accuracy: 0.7657 - val_loss: 1.1398 - val_accuracy: 0.7776
# Epoch 7/40
# 377/377 - 6s - loss: 1.0218 - accuracy: 0.7893 - val_loss: 1.1031 - val_accuracy: 0.7990
# Epoch 8/40
# 377/377 - 6s - loss: 0.9895 - accuracy: 0.8074 - val_loss: 1.0702 - val_accuracy: 0.8100
# Epoch 9/40
# 377/377 - 6s - loss: 0.9595 - accuracy: 0.8224 - val_loss: 1.0938 - val_accuracy: 0.8104
# Epoch 10/40
# 377/377 - 6s - loss: 0.9384 - accuracy: 0.8305 - val_loss: 1.0380 - val_accuracy: 0.8308
# Epoch 11/40
# 377/377 - 6s - loss: 0.9061 - accuracy: 0.8458 - val_loss: 1.0396 - val_accuracy: 0.8239
# Epoch 12/40
# 377/377 - 6s - loss: 0.8880 - accuracy: 0.8545 - val_loss: 1.0129 - val_accuracy: 0.8333
# Epoch 13/40
# 377/377 - 6s - loss: 0.8692 - accuracy: 0.8637 - val_loss: 1.0165 - val_accuracy: 0.8333
# Epoch 14/40
# 377/377 - 7s - loss: 0.8466 - accuracy: 0.8765 - val_loss: 1.0362 - val_accuracy: 0.8358
# Epoch 15/40
# 377/377 - 6s - loss: 0.8316 - accuracy: 0.8799 - val_loss: 1.0117 - val_accuracy: 0.8443
# Epoch 16/40
# 377/377 - 6s - loss: 0.8154 - accuracy: 0.8894 - val_loss: 1.0129 - val_accuracy: 0.8388
# Epoch 17/40
# 377/377 - 7s - loss: 0.8021 - accuracy: 0.8973 - val_loss: 0.9844 - val_accuracy: 0.8532
# Epoch 18/40
# 377/377 - 6s - loss: 0.7902 - accuracy: 0.9009 - val_loss: 1.0042 - val_accuracy: 0.8438
# Epoch 19/40
# 377/377 - 6s - loss: 0.7770 - accuracy: 0.9096 - val_loss: 0.9982 - val_accuracy: 0.8463
# Epoch 20/40
# 377/377 - 7s - loss: 0.7611 - accuracy: 0.9163 - val_loss: 0.9789 - val_accuracy: 0.8577
# Epoch 21/40
# 377/377 - 6s - loss: 0.7527 - accuracy: 0.9193 - val_loss: 0.9831 - val_accuracy: 0.8483
# Epoch 22/40
# 377/377 - 6s - loss: 0.7433 - accuracy: 0.9256 - val_loss: 1.0058 - val_accuracy: 0.8393
# Epoch 23/40
# 377/377 - 6s - loss: 0.7349 - accuracy: 0.9271 - val_loss: 0.9864 - val_accuracy: 0.8463
# Epoch 24/40
# 377/377 - 6s - loss: 0.7299 - accuracy: 0.9299 - val_loss: 0.9933 - val_accuracy: 0.8532
# Epoch 25/40
# 377/377 - 6s - loss: 0.7188 - accuracy: 0.9355 - val_loss: 0.9788 - val_accuracy: 0.8522
# Epoch 26/40
# 377/377 - 8s - loss: 0.7069 - accuracy: 0.9429 - val_loss: 0.9930 - val_accuracy: 0.8612
# Epoch 27/40
# 377/377 - 6s - loss: 0.6970 - accuracy: 0.9464 - val_loss: 0.9994 - val_accuracy: 0.8483
# Epoch 28/40
# 377/377 - 6s - loss: 0.6963 - accuracy: 0.9475 - val_loss: 0.9990 - val_accuracy: 0.8507
# Epoch 29/40
# 377/377 - 6s - loss: 0.6829 - accuracy: 0.9527 - val_loss: 0.9860 - val_accuracy: 0.8522
# Epoch 30/40
# 377/377 - 6s - loss: 0.6763 - accuracy: 0.9554 - val_loss: 1.0156 - val_accuracy: 0.8468
# Epoch 31/40
# 377/377 - 6s - loss: 0.6792 - accuracy: 0.9532 - val_loss: 0.9893 - val_accuracy: 0.8582
# Epoch 32/40
# 377/377 - 6s - loss: 0.6659 - accuracy: 0.9609 - val_loss: 0.9869 - val_accuracy: 0.8572
# Epoch 33/40
# 377/377 - 6s - loss: 0.6686 - accuracy: 0.9565 - val_loss: 0.9740 - val_accuracy: 0.8552
# Epoch 34/40
# 377/377 - 6s - loss: 0.6556 - accuracy: 0.9639 - val_loss: 0.9887 - val_accuracy: 0.8567
# Epoch 35/40
# 377/377 - 6s - loss: 0.6560 - accuracy: 0.9629 - val_loss: 0.9800 - val_accuracy: 0.8612
# Epoch 36/40
# 377/377 - 6s - loss: 0.6528 - accuracy: 0.9646 - val_loss: 0.9941 - val_accuracy: 0.8473
# Epoch 37/40
# 377/377 - 6s - loss: 0.6475 - accuracy: 0.9657 - val_loss: 0.9861 - val_accuracy: 0.8607
# Epoch 38/40
# 377/377 - 6s - loss: 0.6485 - accuracy: 0.9657 - val_loss: 0.9975 - val_accuracy: 0.8547
# Epoch 39/40
# 377/377 - 6s - loss: 0.6374 - accuracy: 0.9712 - val_loss: 0.9879 - val_accuracy: 0.8607
# Epoch 40/40
# 377/377 - 6s - loss: 0.6368 - accuracy: 0.9712 - val_loss: 1.0092 - val_accuracy: 0.8423
# 63/63 [==============================] - 0s 5ms/step - loss: 1.0092 - accuracy: 0.8423
# Processing fold: 2 (8038, 2010)
# Data enhanced (noise) => 24114
# Epoch 1/40
# 377/377 - 7s - loss: 1.6794 - accuracy: 0.4857 - val_loss: 1.5165 - val_accuracy: 0.5985
# Epoch 2/40
# 377/377 - 6s - loss: 1.3749 - accuracy: 0.6204 - val_loss: 1.3456 - val_accuracy: 0.6935
# Epoch 3/40
# 377/377 - 6s - loss: 1.2448 - accuracy: 0.6799 - val_loss: 1.2556 - val_accuracy: 0.7378
# Epoch 4/40
# 377/377 - 6s - loss: 1.1721 - accuracy: 0.7181 - val_loss: 1.1951 - val_accuracy: 0.7428
# Epoch 5/40
# 377/377 - 6s - loss: 1.1106 - accuracy: 0.7481 - val_loss: 1.1335 - val_accuracy: 0.7836
# Epoch 6/40
# 377/377 - 6s - loss: 1.0618 - accuracy: 0.7719 - val_loss: 1.0976 - val_accuracy: 0.7905
# Epoch 7/40
# 377/377 - 6s - loss: 1.0201 - accuracy: 0.7926 - val_loss: 1.1088 - val_accuracy: 0.7915
# Epoch 8/40
# 377/377 - 6s - loss: 0.9876 - accuracy: 0.8084 - val_loss: 1.0794 - val_accuracy: 0.7950
# Epoch 9/40
# 377/377 - 6s - loss: 0.9598 - accuracy: 0.8197 - val_loss: 1.0547 - val_accuracy: 0.8149
# Epoch 10/40
# 377/377 - 6s - loss: 0.9278 - accuracy: 0.8335 - val_loss: 1.0310 - val_accuracy: 0.8214
# Epoch 11/40
# 377/377 - 6s - loss: 0.9113 - accuracy: 0.8456 - val_loss: 1.0253 - val_accuracy: 0.8323
# Epoch 12/40
# 377/377 - 6s - loss: 0.8885 - accuracy: 0.8560 - val_loss: 1.0152 - val_accuracy: 0.8328
# Epoch 13/40
# 377/377 - 6s - loss: 0.8694 - accuracy: 0.8641 - val_loss: 1.0013 - val_accuracy: 0.8383
# Epoch 14/40
# 377/377 - 6s - loss: 0.8506 - accuracy: 0.8737 - val_loss: 0.9990 - val_accuracy: 0.8333
# Epoch 15/40
# 377/377 - 7s - loss: 0.8336 - accuracy: 0.8795 - val_loss: 0.9834 - val_accuracy: 0.8532
# Epoch 16/40
# 377/377 - 6s - loss: 0.8168 - accuracy: 0.8892 - val_loss: 0.9731 - val_accuracy: 0.8488
# Epoch 17/40
# 377/377 - 6s - loss: 0.8074 - accuracy: 0.8933 - val_loss: 0.9939 - val_accuracy: 0.8413
# Epoch 18/40
# 377/377 - 6s - loss: 0.7944 - accuracy: 0.9013 - val_loss: 0.9801 - val_accuracy: 0.8448
# Epoch 19/40
# 377/377 - 6s - loss: 0.7779 - accuracy: 0.9088 - val_loss: 0.9716 - val_accuracy: 0.8527
# Epoch 20/40
# 377/377 - 7s - loss: 0.7663 - accuracy: 0.9126 - val_loss: 0.9619 - val_accuracy: 0.8567
# Epoch 21/40
# 377/377 - 6s - loss: 0.7561 - accuracy: 0.9201 - val_loss: 0.9540 - val_accuracy: 0.8582
# Epoch 22/40
# 377/377 - 6s - loss: 0.7439 - accuracy: 0.9253 - val_loss: 0.9603 - val_accuracy: 0.8577
# Epoch 23/40
# 377/377 - 6s - loss: 0.7310 - accuracy: 0.9324 - val_loss: 0.9614 - val_accuracy: 0.8532
# Epoch 24/40
# 377/377 - 6s - loss: 0.7246 - accuracy: 0.9346 - val_loss: 1.0096 - val_accuracy: 0.8488
# Epoch 25/40
# 377/377 - 7s - loss: 0.7154 - accuracy: 0.9397 - val_loss: 0.9589 - val_accuracy: 0.8672
# Epoch 26/40
# 377/377 - 6s - loss: 0.7079 - accuracy: 0.9417 - val_loss: 0.9485 - val_accuracy: 0.8607
# Epoch 27/40
# 377/377 - 6s - loss: 0.6972 - accuracy: 0.9461 - val_loss: 0.9949 - val_accuracy: 0.8473
# Epoch 28/40
# 377/377 - 6s - loss: 0.6920 - accuracy: 0.9483 - val_loss: 0.9430 - val_accuracy: 0.8627
# Epoch 29/40
# 377/377 - 6s - loss: 0.6802 - accuracy: 0.9540 - val_loss: 0.9644 - val_accuracy: 0.8542
# Epoch 30/40
# 377/377 - 6s - loss: 0.6780 - accuracy: 0.9540 - val_loss: 0.9753 - val_accuracy: 0.8502
# Epoch 31/40
# 377/377 - 7s - loss: 0.6766 - accuracy: 0.9552 - val_loss: 0.9520 - val_accuracy: 0.8687
# Epoch 32/40
# 377/377 - 6s - loss: 0.6651 - accuracy: 0.9593 - val_loss: 0.9852 - val_accuracy: 0.8458
# Epoch 33/40
# 377/377 - 6s - loss: 0.6637 - accuracy: 0.9614 - val_loss: 0.9616 - val_accuracy: 0.8562
# Epoch 34/40
# 377/377 - 6s - loss: 0.6559 - accuracy: 0.9623 - val_loss: 0.9498 - val_accuracy: 0.8632
# Epoch 35/40
# 377/377 - 7s - loss: 0.6521 - accuracy: 0.9650 - val_loss: 0.9415 - val_accuracy: 0.8726
# Epoch 36/40
# 377/377 - 6s - loss: 0.6474 - accuracy: 0.9672 - val_loss: 0.9480 - val_accuracy: 0.8617
# Epoch 37/40
# 377/377 - 6s - loss: 0.6457 - accuracy: 0.9682 - val_loss: 0.9305 - val_accuracy: 0.8657
# Epoch 38/40
# 377/377 - 6s - loss: 0.6359 - accuracy: 0.9721 - val_loss: 0.9386 - val_accuracy: 0.8697
# Epoch 39/40
# 377/377 - 6s - loss: 0.6346 - accuracy: 0.9723 - val_loss: 0.9663 - val_accuracy: 0.8647
# Epoch 40/40
# 377/377 - 6s - loss: 0.6394 - accuracy: 0.9689 - val_loss: 0.9622 - val_accuracy: 0.8642
# 63/63 [==============================] - 0s 6ms/step - loss: 0.9622 - accuracy: 0.8642
# Processing fold: 3 (8039, 2009)
# Data enhanced (noise) => 24117
# Epoch 1/40
# 377/377 - 8s - loss: 1.6717 - accuracy: 0.4898 - val_loss: 1.4859 - val_accuracy: 0.6242
# Epoch 2/40
# 377/377 - 6s - loss: 1.3769 - accuracy: 0.6199 - val_loss: 1.3099 - val_accuracy: 0.7038
# Epoch 3/40
# 377/377 - 6s - loss: 1.2540 - accuracy: 0.6798 - val_loss: 1.2660 - val_accuracy: 0.7158
# Epoch 4/40
# 377/377 - 6s - loss: 1.1712 - accuracy: 0.7195 - val_loss: 1.1976 - val_accuracy: 0.7541
# Epoch 5/40
# 377/377 - 6s - loss: 1.1201 - accuracy: 0.7440 - val_loss: 1.1486 - val_accuracy: 0.7785
# Epoch 6/40
# 377/377 - 6s - loss: 1.0667 - accuracy: 0.7692 - val_loss: 1.1391 - val_accuracy: 0.7840
# Epoch 7/40
# 377/377 - 6s - loss: 1.0314 - accuracy: 0.7856 - val_loss: 1.0992 - val_accuracy: 0.8034
# Epoch 8/40
# 377/377 - 6s - loss: 0.9986 - accuracy: 0.8028 - val_loss: 1.0909 - val_accuracy: 0.8079
# Epoch 9/40
# 377/377 - 6s - loss: 0.9734 - accuracy: 0.8139 - val_loss: 1.0636 - val_accuracy: 0.7994
# Epoch 10/40
# 377/377 - 6s - loss: 0.9419 - accuracy: 0.8308 - val_loss: 1.0261 - val_accuracy: 0.8283
# Epoch 11/40
# 377/377 - 6s - loss: 0.9228 - accuracy: 0.8379 - val_loss: 1.0363 - val_accuracy: 0.8323
# Epoch 12/40
# 377/377 - 6s - loss: 0.8939 - accuracy: 0.8533 - val_loss: 1.0312 - val_accuracy: 0.8233
# Epoch 13/40
# 377/377 - 6s - loss: 0.8744 - accuracy: 0.8630 - val_loss: 1.0068 - val_accuracy: 0.8273
# Epoch 14/40
# 377/377 - 6s - loss: 0.8610 - accuracy: 0.8675 - val_loss: 1.0317 - val_accuracy: 0.8253
# Epoch 15/40
# 377/377 - 6s - loss: 0.8393 - accuracy: 0.8796 - val_loss: 1.0386 - val_accuracy: 0.8248
# Epoch 16/40
# 377/377 - 6s - loss: 0.8280 - accuracy: 0.8829 - val_loss: 1.0000 - val_accuracy: 0.8382
# Epoch 17/40
# 377/377 - 6s - loss: 0.8081 - accuracy: 0.8929 - val_loss: 1.0062 - val_accuracy: 0.8328
# Epoch 18/40
# 377/377 - 6s - loss: 0.7875 - accuracy: 0.9029 - val_loss: 0.9757 - val_accuracy: 0.8542
# Epoch 19/40
# 377/377 - 6s - loss: 0.7788 - accuracy: 0.9073 - val_loss: 0.9897 - val_accuracy: 0.8482
# Epoch 20/40
# 377/377 - 6s - loss: 0.7700 - accuracy: 0.9113 - val_loss: 0.9903 - val_accuracy: 0.8437
# Epoch 21/40
# 377/377 - 6s - loss: 0.7544 - accuracy: 0.9175 - val_loss: 0.9971 - val_accuracy: 0.8497
# Epoch 22/40
# 377/377 - 6s - loss: 0.7436 - accuracy: 0.9248 - val_loss: 0.9994 - val_accuracy: 0.8497
# Epoch 23/40
# 377/377 - 6s - loss: 0.7410 - accuracy: 0.9254 - val_loss: 0.9845 - val_accuracy: 0.8427
# Epoch 24/40
# 377/377 - 6s - loss: 0.7286 - accuracy: 0.9318 - val_loss: 0.9805 - val_accuracy: 0.8507
# Epoch 25/40
# 377/377 - 7s - loss: 0.7145 - accuracy: 0.9378 - val_loss: 0.9638 - val_accuracy: 0.8626
# Epoch 26/40
# 377/377 - 6s - loss: 0.7071 - accuracy: 0.9414 - val_loss: 0.9622 - val_accuracy: 0.8621
# Epoch 27/40
# 377/377 - 7s - loss: 0.6999 - accuracy: 0.9437 - val_loss: 0.9566 - val_accuracy: 0.8666
# Epoch 28/40
# 377/377 - 6s - loss: 0.6987 - accuracy: 0.9441 - val_loss: 0.9744 - val_accuracy: 0.8552
# Epoch 29/40
# 377/377 - 6s - loss: 0.6841 - accuracy: 0.9512 - val_loss: 0.9584 - val_accuracy: 0.8596
# Epoch 30/40
# 377/377 - 6s - loss: 0.6794 - accuracy: 0.9535 - val_loss: 0.9821 - val_accuracy: 0.8522
# Epoch 31/40
# 377/377 - 6s - loss: 0.6667 - accuracy: 0.9583 - val_loss: 0.9787 - val_accuracy: 0.8601
# Epoch 32/40
# 377/377 - 6s - loss: 0.6639 - accuracy: 0.9597 - val_loss: 1.0089 - val_accuracy: 0.8542
# Epoch 33/40
# 377/377 - 6s - loss: 0.6601 - accuracy: 0.9597 - val_loss: 0.9949 - val_accuracy: 0.8542
# Epoch 34/40
# 377/377 - 6s - loss: 0.6628 - accuracy: 0.9585 - val_loss: 1.0039 - val_accuracy: 0.8477
# Epoch 35/40
# 377/377 - 6s - loss: 0.6544 - accuracy: 0.9627 - val_loss: 0.9998 - val_accuracy: 0.8457
# Epoch 36/40
# 377/377 - 6s - loss: 0.6484 - accuracy: 0.9651 - val_loss: 0.9653 - val_accuracy: 0.8651
# Epoch 37/40
# 377/377 - 6s - loss: 0.6386 - accuracy: 0.9693 - val_loss: 0.9797 - val_accuracy: 0.8626
# Epoch 38/40
# 377/377 - 6s - loss: 0.6418 - accuracy: 0.9672 - val_loss: 1.0057 - val_accuracy: 0.8552
# Epoch 39/40
# 377/377 - 7s - loss: 0.6359 - accuracy: 0.9702 - val_loss: 0.9822 - val_accuracy: 0.8686
# Epoch 40/40
# 377/377 - 6s - loss: 0.6312 - accuracy: 0.9720 - val_loss: 0.9600 - val_accuracy: 0.8661
# 63/63 [==============================] - 0s 5ms/step - loss: 0.9600 - accuracy: 0.8661
# Processing fold: 4 (8039, 2009)
# Data enhanced (noise) => 24117
# Epoch 1/40
# 377/377 - 7s - loss: 1.6686 - accuracy: 0.4883 - val_loss: 1.5159 - val_accuracy: 0.6302
# Epoch 2/40
# 377/377 - 6s - loss: 1.3577 - accuracy: 0.6255 - val_loss: 1.3637 - val_accuracy: 0.6829
# Epoch 3/40
# 377/377 - 6s - loss: 1.2423 - accuracy: 0.6820 - val_loss: 1.2445 - val_accuracy: 0.7461
# Epoch 4/40
# 377/377 - 6s - loss: 1.1586 - accuracy: 0.7197 - val_loss: 1.2202 - val_accuracy: 0.7506
# Epoch 5/40
# 377/377 - 6s - loss: 1.1003 - accuracy: 0.7531 - val_loss: 1.1563 - val_accuracy: 0.7820
# Epoch 6/40
# 377/377 - 6s - loss: 1.0597 - accuracy: 0.7733 - val_loss: 1.1124 - val_accuracy: 0.7860
# Epoch 7/40
# 377/377 - 6s - loss: 1.0112 - accuracy: 0.7943 - val_loss: 1.0931 - val_accuracy: 0.8019
# Epoch 8/40
# 377/377 - 6s - loss: 0.9860 - accuracy: 0.8047 - val_loss: 1.0900 - val_accuracy: 0.7944
# Epoch 9/40
# 377/377 - 7s - loss: 0.9519 - accuracy: 0.8224 - val_loss: 1.0619 - val_accuracy: 0.8208
# Epoch 10/40
# 377/377 - 6s - loss: 0.9325 - accuracy: 0.8310 - val_loss: 1.0257 - val_accuracy: 0.8337
# Epoch 11/40
# 377/377 - 6s - loss: 0.9117 - accuracy: 0.8445 - val_loss: 1.0377 - val_accuracy: 0.8308
# Epoch 12/40
# 377/377 - 6s - loss: 0.8821 - accuracy: 0.8577 - val_loss: 1.0482 - val_accuracy: 0.8193
# Epoch 13/40
# 377/377 - 6s - loss: 0.8674 - accuracy: 0.8630 - val_loss: 1.0113 - val_accuracy: 0.8313
# Epoch 14/40
# 377/377 - 6s - loss: 0.8460 - accuracy: 0.8741 - val_loss: 1.0382 - val_accuracy: 0.8193
# Epoch 15/40
# 377/377 - 7s - loss: 0.8257 - accuracy: 0.8849 - val_loss: 0.9753 - val_accuracy: 0.8611
# Epoch 16/40
# 377/377 - 6s - loss: 0.8163 - accuracy: 0.8889 - val_loss: 0.9926 - val_accuracy: 0.8477
# Epoch 17/40
# 377/377 - 6s - loss: 0.8033 - accuracy: 0.8948 - val_loss: 0.9888 - val_accuracy: 0.8522
# Epoch 18/40
# 377/377 - 6s - loss: 0.7833 - accuracy: 0.9040 - val_loss: 0.9815 - val_accuracy: 0.8467
# Epoch 19/40
# 377/377 - 6s - loss: 0.7764 - accuracy: 0.9080 - val_loss: 0.9849 - val_accuracy: 0.8512
# Epoch 20/40
# 377/377 - 6s - loss: 0.7666 - accuracy: 0.9114 - val_loss: 0.9725 - val_accuracy: 0.8517
# Epoch 21/40
# 377/377 - 6s - loss: 0.7513 - accuracy: 0.9194 - val_loss: 0.9745 - val_accuracy: 0.8532
# Epoch 22/40
# 377/377 - 6s - loss: 0.7397 - accuracy: 0.9249 - val_loss: 0.9707 - val_accuracy: 0.8477
# Epoch 23/40
# 377/377 - 6s - loss: 0.7318 - accuracy: 0.9279 - val_loss: 0.9755 - val_accuracy: 0.8601
# Epoch 24/40
# 377/377 - 6s - loss: 0.7213 - accuracy: 0.9339 - val_loss: 0.9627 - val_accuracy: 0.8576
# Epoch 25/40
# 377/377 - 6s - loss: 0.7113 - accuracy: 0.9390 - val_loss: 0.9788 - val_accuracy: 0.8532
# Epoch 26/40
# 377/377 - 6s - loss: 0.7010 - accuracy: 0.9424 - val_loss: 0.9757 - val_accuracy: 0.8547
# Epoch 27/40
# 377/377 - 7s - loss: 0.7016 - accuracy: 0.9433 - val_loss: 0.9610 - val_accuracy: 0.8631
# Epoch 28/40
# 377/377 - 6s - loss: 0.6866 - accuracy: 0.9499 - val_loss: 0.9741 - val_accuracy: 0.8626
# Epoch 29/40
# 377/377 - 6s - loss: 0.6873 - accuracy: 0.9493 - val_loss: 0.9588 - val_accuracy: 0.8547
# Epoch 30/40
# 377/377 - 6s - loss: 0.6794 - accuracy: 0.9530 - val_loss: 0.9561 - val_accuracy: 0.8591
# Epoch 31/40
# 377/377 - 7s - loss: 0.6679 - accuracy: 0.9572 - val_loss: 0.9675 - val_accuracy: 0.8721
# Epoch 32/40
# 377/377 - 6s - loss: 0.6603 - accuracy: 0.9614 - val_loss: 0.9615 - val_accuracy: 0.8626
# Epoch 33/40
# 377/377 - 6s - loss: 0.6592 - accuracy: 0.9625 - val_loss: 0.9741 - val_accuracy: 0.8552
# Epoch 34/40
# 377/377 - 6s - loss: 0.6518 - accuracy: 0.9639 - val_loss: 0.9657 - val_accuracy: 0.8651
# Epoch 35/40
# 377/377 - 6s - loss: 0.6470 - accuracy: 0.9662 - val_loss: 0.9709 - val_accuracy: 0.8651
# Epoch 36/40
# 377/377 - 6s - loss: 0.6489 - accuracy: 0.9647 - val_loss: 0.9719 - val_accuracy: 0.8636
# Epoch 37/40
# 377/377 - 6s - loss: 0.6386 - accuracy: 0.9684 - val_loss: 0.9516 - val_accuracy: 0.8691
# Epoch 38/40
# 377/377 - 6s - loss: 0.6382 - accuracy: 0.9681 - val_loss: 0.9893 - val_accuracy: 0.8571
# Epoch 39/40
# 377/377 - 6s - loss: 0.6340 - accuracy: 0.9723 - val_loss: 0.9621 - val_accuracy: 0.8706
# Epoch 40/40
# 377/377 - 6s - loss: 0.6321 - accuracy: 0.9715 - val_loss: 0.9717 - val_accuracy: 0.8641
# 63/63 [==============================] - 0s 5ms/step - loss: 0.9717 - accuracy: 0.8641

# %%
# 评估
kfcv_evaluate('conv1d', train_data, train_labels)

# {'accuracy': 0.8664415955543519, 'loss': 0.9580374240875242}
# {'accuracy': 0.8672372341156006, 'loss': 0.9618942022323609}  0.7779
# {'accuracy': 0.8688300132751465, 'loss': 0.9568594574928283}  0.775
# {'accuracy': 0.8643508791923523, 'loss': 0.9691726446151732}  0.778
# Out:
# Processing fold: 0 (8038, 2010)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9498 - accuracy: 0.8746
# Processing fold: 1 (8038, 2010)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9930 - accuracy: 0.8612
# Processing fold: 2 (8038, 2010)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9415 - accuracy: 0.8726
# Processing fold: 3 (8039, 2009)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9822 - accuracy: 0.8686
# Processing fold: 4 (8039, 2009)
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9675 - accuracy: 0.8721
# {'accuracy': 0.8698249459266664, 'loss': 0.966798758506775}

# %%
# 推断
infer('conv1d', get_test_data(), data_path + '/dataset/submit_open777.csv')
# Out:
# conv1d loaded.
# result got
# saving...
# - END -
# Your file locates at /content/gdrive/My Drive/jiaozibei/xwbank2020_baseline_keras-master/dataset/result.csv
